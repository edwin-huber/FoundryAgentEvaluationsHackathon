# %% [markdown]
# # Session 1 Solution: Concepts and Evaluation Plan
#
# This notebook captures a practical evaluator selection plan for your Foundry agent.

# %%
evaluation_plan = {
    "agent_behavior": ["task_adherence", "intent_resolution", "tool_call_accuracy"],
    "quality": ["coherence", "relevance"],
    "safety": ["violence", "hate"],
    "target_thresholds": {
        "task_adherence": 0.85,
        "coherence": 0.85,
        "relevance": 0.85
    }
}
evaluation_plan

# %% [markdown]
# ## Next Step
# Use this plan to configure the environment in Session 2 and create datasets in Session 3.
